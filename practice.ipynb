# %%
print("hello world")
print("I am learning python!")
print("programming is fun.")
print("Life is beautiful.")
# Out:
# hello world
# I am learning python!
# programming is fun.
# Life is beautiful.

# %%
student_name = "Motunrayo"
course_name = "Data Science and AI"

print("Welcome,",student_name)
print("You are enrolled in:", course_name )
print("Let's start coding!")
# Out:
# Welcome, Motunrayo
# You are enrolled in: Data Science and AI
# Let's start coding!

# %% [markdown]
# # Hello, I'm Motunrayo
# ## Hello, I'm Motunrayo
# ##### Hello, I'm Motunrayo

# %%
scores= {85, 92, 78,95,88}
print( sum(scores))
average = sum(scores) / len(scores)
print("Average score:", average)

message = "python is amazing"
print("Formatted:", message.title)
file_size_mb =150
if file_size_mb > 100:
    print("file is large - consider compressing it.")
else:
    print("file size is acceptable.")
# Out:
# 438
# Average score: 87.6
# Formatted: <built-in method title of str object at 0x000002728B8EE470>
# file is large - consider compressing it.

# %%
shoe_price = 70000
if shoe_price < 50000:
    print("shoe price consider buying.")
else:
    print("don't buy")
if shoe_price >70000:
    print("buy")
else:
    print("return")
# Out:
# don't buy
# return

# %%
python_uses = [
    "Web Development" ,
    "Data Science" ,
    "Automation",
    "Artificial intelligence" ,
    "Product design"]
print("python is used for:")
for use in python_uses:
    print(" -", use)
print("\nTotal domains:", len(python_uses))
# Out:
# python is used for:
#  - Web Development
#  - Data Science
#  - Automation
#  - Artificial intelligence
#  - Product design
#
# Total domains: 5

# %% [markdown]
# - list one
# - list two

# %%
name = input("please enter your name: ")
age = input ("please input your age: ")
print("\nHello," , name + "!")
print("You are", age, "years old.")
print("Welcome to python programming!")
# Out:
# Hello, !
# You are  years old.
# Welcome to python programming!

# %%
print("=" * 70 )
full_name = input("please enter your full name: ")
level = input("please input your level: ")
department = input("please input your department: ")
hobby = input("please input your hubby: ")
print("\nWelcome," , full_name + "!")
print("You have been enrolled in" , level + "level")
print("in," , department + ".")
print("we have noted you are good at," , hobby + "!")
# Out:
# ======================================================================
#
# Welcome, !
# You have been enrolled in level
# in, .
# we have noted you are good at, !

# %%
Acceptable_age = 17
student_age = int(input("please input age:"))
if student_age >= Acceptable_age:
    print("Welcome" ,"!")
else:
    print("not eligible")
# Out:
# not eligible

# %%
correct_password ="12345"
password = int(input("Enter password"))
if password == correct_password:
    print("successfully logged in")
else:
    print("incorrect password, try again")
# Out:
# incorrect password, try again

# %%
print("=" * 40)
print(2 + 2)
print(10 / 3)
print(10 // 3)
print(10 % 3)
print("hello".upper())
print(len("python"))
# Out:
# ========================================
# 4
# 3.3333333333333335
# 3
# 1
# HELLO
# 6

# %%
# CLASS aCTIVITY 2.3a - print a formatted receipt

item1 = "Notebook"
price1 = 5.50
item2 = "Pen"
price2 = 1.20
item3 = "folder"
price3 = 3.80
total = price1 + price2 + price3


print("=" * 20)
print("       RECEIPT")
print("=" * 20)
print(f"{item1}: #{price1}")
print(f"{item2}: #{price2}")
print(f"{item3}:#{price3}")
print("     total: #", total)
print("=" * 20)
print("  Thanks for your patronage!")
# Out:
# ====================
#        RECEIPT
# ====================
# Notebook: #5.5
# Pen: #1.2
# folder:#3.8
#      total: # 10.5
# ====================
#   Thanks for your patronage!
