# %% [markdown]
# ## Python

# %%
print("hello world")
print("I am learning python!")
print("programming is fun.")
print("Life is beautiful.")
# Out:
# hello world
# I am learning python!
# programming is fun.
# Life is beautiful.

# %%
student_name = "Motunrayo"
course_name = "Data Science and AI"

print("Welcome,",student_name)
print("You are enrolled in:", course_name )
print("Let's start coding!")
# Out:
# Welcome, Motunrayo
# You are enrolled in: Data Science and AI
# Let's start coding!

# %%
# CLASS ACTIVITY 8.1a
subjects = ["Science", "Maths", "English", "Computer", "Crs", "Agric"]  # Add 6 subject names
# Print first, last, and middle 2 subjects
print(subjects[0])
print(subjects[-1])
print(subjects[2])
print(len(subjects))
print(subjects[2:4])
# Out:
# Science
# Agric
# English
# 6
# ['English', 'Computer']

# %% [markdown]
# # Hello, I'm Motunrayo
# ## Hello, I'm Motunrayo
# ##### Hello, I'm Motunrayo

# %%
# Class Activity 1. 1a
# Replace "Your name" with your actual name
# Replace each "Goal X" with something real you want to build

my_name = "Motunrayo"

print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
scores= {85, 92, 78,95,88}
print( sum(scores))
average = sum(scores) / len(scores)
print("Average score:", average)

message = "python is amazing"
print("Formatted:", message.title())
file_size_mb =150
if file_size_mb > 100:
    print("file is large - consider compressing it.")
else:
    print("file size is acceptable.")
# Out:
# 438
# Average score: 87.6
# Formatted: Python Is Amazing
# file is large - consider compressing it.

# %%
shoe_price = 70000
if shoe_price < 50000:
    print("shoe price consider buying.")
else:
    print("don't buy")
if shoe_price >70000:
    print("buy")
else:
    print("return")
# Out:
# don't buy
# return

# %%
python_uses = [
    "Web Development" ,
    "Data Science" ,
    "Automation",
    "Artificial intelligence" ,
    "Product design"]
print("python is used for:")
for use in python_uses:
    print(" -", use)
print("\nTotal domains:", len(python_uses))
# Out:
# python is used for:
#  - Web Development
#  - Data Science
#  - Automation
#  - Artificial intelligence
#  - Product design
#
# Total domains: 5

# %% [markdown]
# - list one
# - list two

# %%
name = input("please enter your name: ")
age = input ("please input your age: ")
print("\nHello,", name + "!")
print("You are", age, "years old.")
print("Welcome to python programming!")
# Out:
# Hello, Motunrayo!
# You are 22 years old.
# Welcome to python programming!

# %%
print("=" * 70 )
full_name = input("please enter your full name: ")
level = input("please input your level: ")
department = input("please input your department: ")
hobby = input("please input your hubby: ")
print("\nWelcome," , full_name + "!")
print("You have been enrolled in", level + "level")
print("in," , department + ".")
print("we have noted you are good at,", hobby + "!")
# Out:
# ======================================================================
#
# Welcome, Alayaki Motunrayo!
# You have been enrolled in 200level
# in, Data Science.
# we have noted you are good at, Cooking!

# %%
Acceptable_age = 17
student_age = int( input("please input age: "))
if Acceptable_age < student_age:
    print("Welcome","!")
else:
    print("not eligible")
# Out:
# Welcome !

# %%
Box = ["pen", "book", "eraser", "crayon"]
Box.append("pencils")
print("After append:", Box)
Box.insert(0,"pin")
print("After insert:", Box)
# Out:
# After append: ['pen', 'book', 'eraser', 'crayon', 'pencils']
# After insert: ['pin', 'pen', 'book', 'eraser', 'crayon', 'pencils']

# %%
Cupboard = ["kettle", "pots", "trays", "flask"]
Cupboard.pop(1)
print("After pop:", Cupboard)
Cupboard.remove("kettle")
print("After remove:", Cupboard)
# Out:
# After pop: ['kettle', 'trays', 'flask']
# After remove: ['trays', 'flask']

# %%
Birthday = (15, "August", 2005)
print(Birthday)
print("Day:")
print(Birthday[0])

print("Month:")
print(Birthday[1])

print("year:")
print(Birthday[2])
# Out:
# (15, 'August', 2005)
# Day:
# 15
# Month:
# August
# year:
# 2005
